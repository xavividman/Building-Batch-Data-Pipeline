# %% [markdown]
# ## This notebook explains the data extraction and how the data looks like through all the transformations

# %% [markdown]
# ### Importing libraries

# %%
import pandas as pd
import yfinance as yf
import numpy as np

# %% [markdown]
# ### Exctracting data from Yahoo Finance API
#
# Here, we need to specify:
# - company_symbol: the company (or multiple companies) symbol
# - start_date: the date you want to start extracting data
# - end_date: the before last date you want to extract data. The date that you specify here is not included

# %%
company_symbol = ['AAPL', 'AMZN', 'GOOGL', 'MSFT']
start_date = '2023-08-01'
end_date = '2023-09-01'

df = yf.download(tickers=company_symbol, start=start_date, end=end_date, interval='1h')
df.head(3)
# Out:
# [*********************100%%**********************]  4 of 4 completed
#                             Adj Close                                      \
#                                  AAPL        AMZN       GOOGL        MSFT
# Datetime
# 2023-08-01 09:30:00-04:00  195.475006  131.949997  131.990005  335.720001
# 2023-08-01 10:30:00-04:00  196.115005  132.619995  132.160004  337.713287
# 2023-08-01 11:30:00-04:00  195.497299  132.179993  131.714996  337.234985
#
#                                 Close                                      \
#                                  AAPL        AMZN       GOOGL        MSFT
# Datetime
# 2023-08-01 09:30:00-04:00  195.475006  131.949997  131.990005  335.720001
# 2023-08-01 10:30:00-04:00  196.115005  132.619995  132.160004  337.713287
# 2023-08-01 11:30:00-04:00  195.497299  132.179993  131.714996  337.234985
#
#                                  High              ...         Low  \
#                                  AAPL        AMZN  ...       GOOGL
# Datetime                                           ...
# 2023-08-01 09:30:00-04:00  196.729996  133.320007  ...  130.679993
# 2023-08-01 10:30:00-04:00  196.179993  132.830002  ...  131.929993
# 2023-08-01 11:30:00-04:00  196.145004  132.955002  ...  131.690002
#
#                                              Open                          \
#                                  MSFT        AAPL        AMZN       GOOGL
# Datetime
# 2023-08-01 09:30:00-04:00  333.700012  196.235001  133.110001  130.774994
# 2023-08-01 10:30:00-04:00  335.619995  195.479996  131.940002  131.979996
# 2023-08-01 11:30:00-04:00  337.000000  196.110001  132.609894  132.149994
#
#                                         Volume
#                                  MSFT     AAPL      AMZN    GOOGL     MSFT
# Datetime
# 2023-08-01 09:30:00-04:00  335.190002  9552101  12831826  7684072  4617472
# 2023-08-01 10:30:00-04:00  335.757996  4389743   5598671  2815607  3152370
# 2023-08-01 11:30:00-04:00  337.700012  2991657   4845837  1910273  1669609
#
# [3 rows x 24 columns]

# %% [markdown]
# ### Reshaping DataFrame to have more readable column indices

# %%
df = df.stack(level=1).reset_index().rename(columns={'level_1':'company'})
df.head()
# Out:
#                    Datetime company   Adj Close       Close        High  \
# 0 2023-08-01 09:30:00-04:00    AAPL  195.475006  195.475006  196.729996
# 1 2023-08-01 09:30:00-04:00    AMZN  131.949997  131.949997  133.320007
# 2 2023-08-01 09:30:00-04:00   GOOGL  131.990005  131.990005  132.350006
# 3 2023-08-01 09:30:00-04:00    MSFT  335.720001  335.720001  335.820007
# 4 2023-08-01 10:30:00-04:00    AAPL  196.115005  196.115005  196.179993
#
#           Low        Open    Volume
# 0  195.279999  196.235001   9552101
# 1  131.619904  133.110001  12831826
# 2  130.679993  130.774994   7684072
# 3  333.700012  335.190002   4617472
# 4  195.330002  195.479996   4389743

# %% [markdown]
# ### Standardizing column names and rounding float numbers to 2 digits

# %%
df.columns = [i.replace(' ', '_').lower() for i in df.columns]

numeric_cols = df.select_dtypes(include=[np.number]).columns
df[numeric_cols] = df[numeric_cols].round(2)
df.head()
# Out:
#                    datetime company  adj_close   close    high     low  \
# 0 2023-08-01 09:30:00-04:00    AAPL     195.48  195.48  196.73  195.28
# 1 2023-08-01 09:30:00-04:00    AMZN     131.95  131.95  133.32  131.62
# 2 2023-08-01 09:30:00-04:00   GOOGL     131.99  131.99  132.35  130.68
# 3 2023-08-01 09:30:00-04:00    MSFT     335.72  335.72  335.82  333.70
# 4 2023-08-01 10:30:00-04:00    AAPL     196.12  196.12  196.18  195.33
#
#      open    volume
# 0  196.24   9552101
# 1  133.11  12831826
# 2  130.77   7684072
# 3  335.19   4617472
# 4  195.48   4389743

# %% [markdown]
# ### Verifying that variable types are correct

# %%
df.dtypes
# Out:
# datetime     datetime64[ns, America/New_York]
# company                                object
# adj_close                             float64
# close                                 float64
# high                                  float64
# low                                   float64
# open                                  float64
# volume                                  int64
# dtype: object
